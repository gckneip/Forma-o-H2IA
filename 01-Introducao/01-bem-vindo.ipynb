# %% [markdown]
# # Bem-vindo à Formação H2IA!
#
# ## Sobre este curso
#
# Este curso foi desenvolvido para preparar profissionais para trabalhar no Hub de Inteligência Artificial da UFPEL. Ao longo desta formação, você aprenderá sobre os diferentes campos da Inteligência Artificial.
#
# ## Estrutura do Curso
#
# 1. **Introdução** - Fundamentos e preparação do ambiente
# 2. **Data Science** - Análise e manipulação de dados
# 3. **Machine Learning** - Algoritmos de aprendizado de máquina
# 4. **Deep Learning** - Redes neurais profundas
# 5. **NLP** - Processamento de Linguagem Natural
# 6. **Visão Computacional** - Processamento de imagens
# 7. **Projetos** - Aplicação prática dos conhecimentos
#
# ## Configuração do Ambiente
#
# Vamos começar verificando se o Python está instalado corretamente.

# %%
import sys
print(f"Versão do Python: {sys.version}")
print(f"Executável: {sys.executable}")

# %% [markdown]
# ## Instalação de Bibliotecas Essenciais
#
# Execute o comando abaixo para instalar as bibliotecas necessárias (descomente para executar):

# %%
# !pip install numpy pandas matplotlib scikit-learn jupyter

# %% [markdown]
# ## Verificando as Instalações

# %%
try:
    import numpy as np
    import pandas as pd
    import matplotlib.pyplot as plt
    import sklearn
    
    print("✓ NumPy versão:", np.__version__)
    print("✓ Pandas versão:", pd.__version__)
    print("✓ Matplotlib versão:", plt.__version__)
    print("✓ Scikit-learn versão:", sklearn.__version__)
    print("\nTodas as bibliotecas estão instaladas corretamente!")
except ImportError as e:
    print(f"Erro ao importar biblioteca: {e}")
    print("Execute a célula anterior para instalar as bibliotecas necessárias.")

# %% [markdown]
# ## Próximos Passos
#
# Agora que seu ambiente está configurado, você pode prosseguir para:
# - `02-python-basico.ipynb` - Revisão de conceitos de Python
# - `03-bibliotecas-essenciais.ipynb` - Introdução às bibliotecas principais
#
# Boa sorte em sua jornada no mundo da Inteligência Artificial! 🚀
